# %% [markdown]
# this notebook is used to merge the information sheet from the 3 exhanges: NASDAQ, NYSE and AMEX

# %%
from os import listdir
from os.path import isfile, join
import pandas as pd

# %%
mypath = r"C:\Users\yu guang\Desktop\us_tickers_download"
onlyfiles = [f for f in listdir(mypath) if 'nasdaq_screener_' in f]

df = pd.DataFrame()

for i in range(len(onlyfiles)):
    df2 = pd.read_csv(mypath + r"\\" + onlyfiles[i])
    df = df.append(df2, ignore_index=True)

df = df.dropna(subset=["Sector"])
df.reset_index(drop=True, inplace=True)
df = df[~df['Symbol'].str.contains("\^|\/")]
df.reset_index(drop=True, inplace=True)

display(df)
df.to_csv(mypath + r"\\" + "us_tickers_summary.csv", index=False)
# Out:
#      Symbol                                              Name Last Sale  \
# 0      AACG  ATA Creativity Global American Depositary Shares     $2.99
# 1      AACQ      Artius Acquisition Inc. Class A Common Stock    $10.03
# 2     AACQU                     Artius Acquisition Inc. Unit     $10.60
# 3     AACQW                    Artius Acquisition Inc Warrant     $1.74
# 4       AAL         American Airlines Group Inc. Common Stock    $21.55
# ...     ...                                               ...       ...
# 6298   XTNT          Xtant Medical Holdings Inc. Common Stock     $1.91
# 6299   XXII              22nd Century Group Inc. Common Stock     $3.55
# 6300   YCBD                           cbdMD Inc. Common Stock     $3.36
# 6301   ZDGE                  Zedge Inc. Class B Common Stock     $12.34
# 6302    ZOM                      Zomedica Corp. Common Shares   $0.8466
#
#       Net Change % Change    Market Cap        Country  IPO Year    Volume  \
# ...
